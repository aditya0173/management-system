# %% [markdown]
# # Management System API Testing
#
# This notebook provides comprehensive testing for all REST API endpoints in the Management System backend.
#
# ## Table of Contents
# 1. [Setup & Configuration](#setup)
# 2. [Authentication APIs](#authentication)
# 3. [User Management APIs](#users)
# 4. [Employee Management APIs](#employees)
# 5. [Client Management APIs](#clients)
# 6. [Client Unit APIs](#client-units)
# 7. [Department Contact APIs](#department-contacts)
#
# ---

# %% [markdown]
# ## 1. Setup & Configuration <a id="setup"></a>
#
# Install required packages and configure the base URL and authentication.

# %%
# Install required packages (run once)
# !pip install requests python-dotenv

# %%
import requests
import json
from datetime import datetime, timedelta
from pprint import pprint

# Configuration
BASE_URL = "http://localhost:8000/api"  # Change this to your backend URL
HEADERS = {"Content-Type": "application/json"}

# Global variables to store tokens
ACCESS_TOKEN = None
REFRESH_TOKEN = None

# Helper function to update headers with token
def set_auth_token(token):
    global HEADERS
    HEADERS["Authorization"] = f"Bearer {token}"

# Helper function to print responses
def print_response(response, title="Response"):
    print(f"\n{'='*60}")
    print(f"{title}")
    print(f"{'='*60}")
    print(f"Status Code: {response.status_code}")
    print(f"\nResponse Body:")
    try:
        pprint(response.json())
    except:
        print(response.text)
    print(f"{'='*60}\n")

print("✅ Setup complete!")
print(f"Base URL: {BASE_URL}")
# Out:
# ✅ Setup complete!
# Base URL: http://localhost:8000/api

# %% [markdown]
# ---
# ## 2. Authentication APIs <a id="authentication"></a>
#
# Test JWT authentication endpoints: login, token refresh, and token verification.

# %% [markdown]
# ### 2.1 User Registration
#
# Create a new user account for testing.

# %%
# Register a new user
register_data = {
    "name": "Test User",
    "username": "Test User",
    "email": "testuser@example.com",
    "password": "TestPassword123!",
    "password_confirm": "TestPassword123!"
}

response = requests.post(f"{BASE_URL}/users/", json=register_data, headers=HEADERS)
print_response(response, "User Registration")

if response.status_code == 201:
    user_data = response.json()
    USER_ID = user_data.get('id')
    print(f"✅ User created successfully with ID: {USER_ID}")
else:
    print("❌ Registration failed. You may use existing credentials for login.")
# Out:
# ============================================================
# User Registration
# ============================================================
# Status Code: 400
#
# Response Body:
# {'email': ['User with this email already exists.']}
# ============================================================
#
# ❌ Registration failed. You may use existing credentials for login.

# %% [markdown]
# ### 2.2 Login (Obtain JWT Token)
#
# Login with credentials to get access and refresh tokens.

# %%
# Login to get JWT tokens
login_data = {
    # "username": "Test User",
    "email": "testuser@example.com",
    "password": "TestPassword123!"
}

response = requests.post(f"{BASE_URL}/token/", json=login_data, headers=HEADERS)
print_response(response, "Login (Token Obtain)")

if response.status_code == 200:
    tokens = response.json()
    ACCESS_TOKEN = tokens.get('access')
    REFRESH_TOKEN = tokens.get('refresh')
    set_auth_token(ACCESS_TOKEN)
    print("✅ Login successful! Token set in headers.")
else:
    print(response.text)
    print("❌ Login failed!")
# Out:
# ============================================================
# Login (Token Obtain)
# ============================================================
# Status Code: 200
#
# Response Body:
# {'access': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ0b2tlbl90eXBlIjoiYWNjZXNzIiwiZXhwIjoxNzcwOTA1MDA0LCJpYXQiOjE3NzA5MDE0MDQsImp0aSI6IjU1YTNjMjgwZmRhMzRiMzFiNDE5NjJmZDgyZGI1MDJiIiwidXNlcl9pZCI6IjEifQ.71cncI6Kepr_Y0BKzDF_Ypp92d1w0p1elqt7kAUeTKU',
#  'refresh': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ0b2tlbl90eXBlIjoicmVmcmVzaCIsImV4cCI6MTc3MTUwNjIwNCwiaWF0IjoxNzcwOTAxNDA0LCJqdGkiOiI5NWQyMjRiZTcwMmY0ZDdiOGRmOTAxMmRlYmMwZTZkNCIsInVzZXJfaWQiOiIxIn0.Gff_UnMYLqS_XgS5scyZzmniBFQus6zgU7K7OFBp0so'}
# ============================================================
#
# ✅ Login successful! Token set in headers.

# %% [markdown]
# ### 2.3 Verify Token
#
# Verify that the access token is valid.

# %%
# Verify the access token
verify_data = {"token": ACCESS_TOKEN}

response = requests.post(f"{BASE_URL}/token/verify/", json=verify_data, headers=HEADERS)
print_response(response, "Token Verification")

if response.status_code == 200:
    print("✅ Token is valid!")
else:
    print("❌ Token is invalid or expired!")
# Out:
# ============================================================
# Token Verification
# ============================================================
# Status Code: 200
#
# Response Body:
# {}
# ============================================================
#
# ✅ Token is valid!

# %% [markdown]
# ### 2.4 Refresh Token
#
# Get a new access token using the refresh token.

# %%
# Refresh the access token
refresh_data = {"refresh": REFRESH_TOKEN}

response = requests.post(f"{BASE_URL}/token/refresh/", json=refresh_data, headers=HEADERS)
print_response(response, "Token Refresh")

if response.status_code == 200:
    new_tokens = response.json()
    ACCESS_TOKEN = new_tokens.get('access')
    set_auth_token(ACCESS_TOKEN)
    print("✅ Token refreshed successfully!")
else:
    print("❌ Token refresh failed!")
# Out:
# ============================================================
# Token Refresh
# ============================================================
# Status Code: 200
#
# Response Body:
# {'access': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ0b2tlbl90eXBlIjoiYWNjZXNzIiwiZXhwIjoxNzcwOTEwMTU1LCJpYXQiOjE3NzA5MDY1NTUsImp0aSI6IjU0ODk3ZWVmNjBhZDQyMTFiMjdiZGJiMmY3NWYzMmY4IiwidXNlcl9pZCI6IjEifQ.QToA1_6_KlTeGXTzWso1JANKKsMGRzDB-pYWuemKVek',
#  'refresh': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ0b2tlbl90eXBlIjoicmVmcmVzaCIsImV4cCI6MTc3MTUxMTM1NSwiaWF0IjoxNzcwOTA2NTU1LCJqdGkiOiJkODA0ZDg3YjAwYzE0NGNiYTJiMzk0MzQ5OWFlYzExNiIsInVzZXJfaWQiOiIxIn0.FJyOvHpCBwHovX0zcak1J8ZkAlbV0RBvrSMIRWOOoLk'}
# ============================================================
#
# ✅ Token refreshed successfully!

# %% [markdown]
# ---
# ## 3. User Management APIs <a id="users"></a>
#
# Test all user management endpoints.

# %% [markdown]
# ### 3.1 Get Current User Profile (Me)
#
# Retrieve the authenticated user's profile.

# %%
# Get current user profile
response = requests.get(f"{BASE_URL}/users/me/", headers=HEADERS)
print_response(response, "Current User Profile")

if response.status_code == 200:
    print("✅ Profile retrieved successfully!")
else:
    print("❌ Failed to retrieve profile!")
# Out:
# ============================================================
# Current User Profile
# ============================================================
# Status Code: 200
#
# Response Body:
# {'created_at': '2026-02-12 12:40:12',
#  'email': 'testuser@example.com',
#  'id': 1,
#  'is_active': True,
#  'is_staff': False,
#  'is_superuser': False,
#  'last_login': '2026-02-12 13:03:24',
#  'name': 'Test User',
#  'updated_at': '2026-02-12 12:40:12'}
# ============================================================
#
# ✅ Profile retrieved successfully!

# %% [markdown]
# ### 3.2 List All Users
#
# Get a list of all users (Admin only).

# %%
# List all users
response = requests.get(f"{BASE_URL}/users/", headers=HEADERS)
print_response(response, "List All Users")

if response.status_code == 200:
    users = response.json()
    print(f"✅ Found {len(users)} users")
else:
    print("❌ Failed to retrieve users (may require admin privileges)")
# Out:
# ============================================================
# List All Users
# ============================================================
# Status Code: 200
#
# Response Body:
# {'count': 1,
#  'next': None,
#  'previous': None,
#  'results': [{'created_at': '2026-02-12 12:40:12',
#               'email': 'testuser@example.com',
#               'id': 1,
#               'is_active': True,
#               'is_staff': False,
#               'is_superuser': False,
#               'name': 'Test User',
#               'updated_at': '2026-02-12 12:40:12'}]}
# ============================================================
#
# ✅ Found 4 users

# %% [markdown]
# ### 3.3 Get User by ID
#
# Retrieve details of a specific user.

# %%
# Get user by ID (replace with actual user ID)
user_id = 1  # Change this to a valid user ID

response = requests.get(f"{BASE_URL}/users/{user_id}/", headers=HEADERS)
print_response(response, f"Get User {user_id}")

if response.status_code == 200:
    print("✅ User details retrieved successfully!")
else:
    print("❌ Failed to retrieve user details!")
# Out:
# ============================================================
# Get User 1
# ============================================================
# Status Code: 200
#
# Response Body:
# {'created_at': '2026-02-12 12:40:12',
#  'email': 'testuser@example.com',
#  'id': 1,
#  'is_active': True,
#  'is_staff': False,
#  'is_superuser': False,
#  'last_login': '2026-02-12 13:03:24',
#  'name': 'Test User',
#  'updated_at': '2026-02-12 12:40:12'}
# ============================================================
#
# ✅ User details retrieved successfully!

# %% [markdown]
# ### 3.4 Update User
#
# Update user information (partial update).

# %%
# Update user (PATCH request)
user_id = 1  # Change this to a valid user ID
update_data = {
    "name": "Updated Test User"
}

response = requests.patch(f"{BASE_URL}/users/{user_id}/", json=update_data, headers=HEADERS)
print_response(response, f"Update User {user_id}")

if response.status_code == 200:
    print("✅ User updated successfully!")
else:
    print("❌ Failed to update user!")
# Out:
# ============================================================
# Update User 1
# ============================================================
# Status Code: 200
#
# Response Body:
# {'email': 'testuser@example.com',
#  'is_active': True,
#  'name': 'Updated Test User'}
# ============================================================
#
# ✅ User updated successfully!

# %% [markdown]
# ### 3.5 Change Password
#
# Change the password for the authenticated user.

# %%
# Change password
password_data = {
    "old_password": "TestPassword123!",
    "new_password": "NewPassword123!",
    "new_password_confirm": "NewPassword123!"
}

response = requests.post(f"{BASE_URL}/users/change_password/", json=password_data, headers=HEADERS)
print_response(response, "Change Password")

if response.status_code == 200:
    print("✅ Password changed successfully!")
else:
    print("❌ Failed to change password!")
# Out:
# ============================================================
# Change Password
# ============================================================
# Status Code: 200
#
# Response Body:
# {'message': 'Password changed successfully'}
# ============================================================
#
# ✅ Password changed successfully!

# %% [markdown]
# ### 3.6 User Statistics
#
# Get user statistics (Admin only).

# %%
# Get user statistics
response = requests.get(f"{BASE_URL}/users/statistics/", headers=HEADERS)
print_response(response, "User Statistics")

if response.status_code == 200:
    print("✅ Statistics retrieved successfully!")
else:
    print("❌ Failed to retrieve statistics (may require admin privileges)!")
# Out:
# ============================================================
# User Statistics
# ============================================================
# Status Code: 200
#
# Response Body:
# {'active_users': 1, 'staff_users': 0, 'superusers': 0, 'total_users': 1}
# ============================================================
#
# ✅ Statistics retrieved successfully!

# %% [markdown]
# ### 3.7 Delete User
#
# Delete a user (Admin only).

# %%
# Delete user (Admin only - use with caution!)
# user_id = 999  # Change this to a valid user ID you want to delete

# response = requests.delete(f"{BASE_URL}/users/{user_id}/", headers=HEADERS)
# print_response(response, f"Delete User {user_id}")

# if response.status_code == 204:
#     print("✅ User deleted successfully!")
# else:
#     print("❌ Failed to delete user!")

print("⚠️ Delete user endpoint commented out for safety. Uncomment to test.")
# Out:
# ⚠️ Delete user endpoint commented out for safety. Uncomment to test.

# %% [markdown]
# ---
# ## 4. Employee Management APIs <a id="employees"></a>
#
# Test all employee management endpoints.

# %% [markdown]
# ### 4.1 Create Employee
#
# Create a new employee record.

# %%
# Create a new employee
employee_data = {
    "employeeCode": "EMP001",
    "firstName": "John",
    "middleName": "Michael",
    "lastName": "Doe",
    "fatherName": "Robert Doe",
    "motherName": "Mary Doe",
    "dob": "1990-01-15T00:00:00Z",
    "gender": "Male",
    "maritalStatus": True,
    "spouseName": "Jane Doe",
    "email": "john.doe@example.com",
    "phone": "+1234567890",
    "mobileHome": "+0987654321",
    "position": "Software Engineer",
    "department": "IT",
    "hireDate": "2020-01-01",
    "salary": "75000.00",
    "height": "180cm",
    "weight": "75kg",
    "bloodGroup": "O+",
    "presentStreet": "123 Main St",
    "presentCity": "New York",
    "presentState": "NY",
    "permanentStreet": "123 Main St",
    "permanentCity": "New York",
    "permanentState": "NY",
    "aadharNumber": "1234-5678-9012",
    "panNumber": "ABCDE1234F"
}

response = requests.post(f"{BASE_URL}/employee/", json=employee_data, headers=HEADERS)
print_response(response, "Create Employee")

if response.status_code == 201:
    employee = response.json()
    EMPLOYEE_ID = employee.get('id')
    print(f"✅ Employee created successfully with ID: {EMPLOYEE_ID}")
else:
    print("❌ Failed to create employee!")
# Out:
# ============================================================
# Create Employee
# ============================================================
# Status Code: 201
#
# Response Body:
# {'aadharNumber': '1234-5678-9012',
#  'bankAccountNumber': None,
#  'bloodGroup': 'O+',
#  'branchName': None,
#  'certifications': None,
#  'department': 'IT',
#  'dob': '1990-01-15 00:00:00',
#  'documents': None,
#  'email': 'john.doe@example.com',
#  'employeeCode': 'EMP001',
#  'esicIPNumber': None,
#  'fatherName': 'Robert Doe',
#  'firstName': 'John',
#  'gender': 'Male',
#  'height': '180cm',
#  'hireDate': '2020-01-01',
#  'id': 2,
#  'identificationMark': None,
#  'ifscCode': None,
#  'is_active': True,
#  'lastName': 'Doe',
#  'maritalStatus': True,
#  'middleName': 'Michael',
#  'mobileHome': '+0987654321',
#  'motherName': 'Mary Doe',
#  'panNumber': 'ABCDE1234F',
#  'permanentCity': 'New York',
#  'permanentState': 'NY',
#  'permanentStreet': '123 Main St',
#  'pfNumbe': None,
#  'phone': '+1234567890',
#  'position': 'Software Engineer',
#  'presentCity': 'New York',
#  'presentState': 'NY',
#  'presentStreet': '123 Main St',
#  'salary': '75000.00',
#  'salaryDetails': None,
#  'shirtSize': None,
#  'shoeSize': None,
#  'spouseName': 'Jane Doe',
#  'trouserSize': None,
#  'uanNumber': None,
#  'weight': '75kg'}
# ============================================================
#
# ✅ Employee created successfully with ID: 2

# %% [markdown]
# ### 4.2 List All Employees
#
# Get a list of all employees.

# %%
# List all employees
response = requests.get(f"{BASE_URL}/employee/", headers=HEADERS)
print_response(response, "List All Employees")

if response.status_code == 200:
    employees = response.json()
    print(f"✅ Found {len(employees)} employees")
else:
    print("❌ Failed to retrieve employees!")
# Out:
# ============================================================
# List All Employees
# ============================================================
# Status Code: 200
#
# Response Body:
# {'count': 2,
#  'next': None,
#  'previous': None,
#  'results': [{'aadharNumber': '1234-5678-9012',
#               'bankAccountNumber': None,
#               'bloodGroup': 'O+',
#               'branchName': None,
#               'certifications': None,
#               'department': 'IT',
#               'dob': '1990-01-15 00:00:00',
#               'documents': None,
#               'email': 'john.doe@example.com',
#               'employeeCode': 'EMP001',
#               'esicIPNumber': None,
#               'fatherName': 'Robert Doe',
#               'firstName': 'John',
#               'gender': 'Male',
#               'height': '180cm',
#               'hireDate': '2020-01-01',
#               'id': 1,
#               'identificationMark': None,
#               'ifscCode': None,
#               'is_active': True,
#               'lastName': 'Doe',
#               'maritalStatus': True,
#               'middleName': 'Michael',
#               'mobileHome': '+0987654321',
#               'motherName': 'Mary Doe',
#               'panNumber': 'ABCDE1234F',
#               'permanentCity': 'New York',
#               'permanentState': 'NY',
#               'permanentStreet': '123 Main St',
#               'pfNumbe': None,
#               'phone': '+1234567890',
#               'position': 'Senior Software Engineer',
#               'presentCity': 'New York',
#               'presentState': 'NY',
#               'presentStreet': '123 Main St',
#               'salary': '85000.00',
#               'salaryDetails': None,
#               'shirtSize': None,
#               'shoeSize': None,
#               'spouseName': 'Jane Doe',
#               'trouserSize': None,
#               'uanNumber': None,
#               'weight': '75kg'},
#              {'aadharNumber': '1234-5678-9012',
#               'bankAccountNumber': None,
#               'bloodGroup': 'O+',
#               'branchName': None,
#               'certifications': None,
#               'department': 'IT',
#               'dob': '1990-01-15 00:00:00',
#               'documents': None,
#               'email': 'john.doe@example.com',
#               'employeeCode': 'EMP001',
#               'esicIPNumber': None,
#               'fatherName': 'Robert Doe',
#               'firstName': 'John',
#               'gender': 'Male',
#               'height': '180cm',
#               'hireDate': '2020-01-01',
#               'id': 2,
#               'identificationMark': None,
#               'ifscCode': None,
#               'is_active': True,
#               'lastName': 'Doe',
#               'maritalStatus': True,
#               'middleName': 'Michael',
#               'mobileHome': '+0987654321',
#               'motherName': 'Mary Doe',
#               'panNumber': 'ABCDE1234F',
#               'permanentCity': 'New York',
#               'permanentState': 'NY',
#               'permanentStreet': '123 Main St',
#               'pfNumbe': None,
#               'phone': '+1234567890',
#               'position': 'Software Engineer',
#               'presentCity': 'New York',
#               'presentState': 'NY',
#               'presentStreet': '123 Main St',
#               'salary': '75000.00',
#               'salaryDetails': None,
#               'shirtSize': None,
#               'shoeSize': None,
#               'spouseName': 'Jane Doe',
#               'trouserSize': None,
#               'uanNumber': None,
#               'weight': '75kg'}]}
# ============================================================
#
# ✅ Found 4 employees

# %% [markdown]
# ### 4.3 Get Employee by ID
#
# Retrieve details of a specific employee.

# %%
# Get employee by ID
employee_id = 1  # Change this to a valid employee ID

response = requests.get(f"{BASE_URL}/employee/{employee_id}/", headers=HEADERS)
print_response(response, f"Get Employee {employee_id}")

if response.status_code == 200:
    print("✅ Employee details retrieved successfully!")
else:
    print("❌ Failed to retrieve employee details!")
# Out:
# ============================================================
# Get Employee 1
# ============================================================
# Status Code: 200
#
# Response Body:
# {'aadharNumber': '1234-5678-9012',
#  'bankAccountNumber': None,
#  'bloodGroup': 'O+',
#  'branchName': None,
#  'certifications': None,
#  'department': 'IT',
#  'dob': '1990-01-15 00:00:00',
#  'documents': None,
#  'email': 'john.doe@example.com',
#  'employeeCode': 'EMP001',
#  'esicIPNumber': None,
#  'fatherName': 'Robert Doe',
#  'firstName': 'John',
#  'gender': 'Male',
#  'height': '180cm',
#  'hireDate': '2020-01-01',
#  'id': 1,
#  'identificationMark': None,
#  'ifscCode': None,
#  'is_active': True,
#  'lastName': 'Doe',
#  'maritalStatus': True,
#  'middleName': 'Michael',
#  'mobileHome': '+0987654321',
#  'motherName': 'Mary Doe',
#  'panNumber': 'ABCDE1234F',
#  'permanentCity': 'New York',
#  'permanentState': 'NY',
#  'permanentStreet': '123 Main St',
#  'pfNumbe': None,
#  'phone': '+1234567890',
#  'position': 'Senior Software Engineer',
#  'presentCity': 'New York',
#  'presentState': 'NY',
#  'presentStreet': '123 Main St',
#  'salary': '85000.00',
#  'salaryDetails': None,
#  'shirtSize': None,
#  'shoeSize': None,
#  'spouseName': 'Jane Doe',
#  'trouserSize': None,
#  'uanNumber': None,
#  'weight': '75kg'}
# ============================================================
#
# ✅ Employee details retrieved successfully!

# %% [markdown]
# ### 4.4 Update Employee
#
# Update employee information.

# %%
# Update employee
employee_id = 1  # Change this to a valid employee ID
update_data = {
    "position": "Senior Software Engineer",
    "salary": "85000.00"
}

response = requests.patch(f"{BASE_URL}/employee/{employee_id}/", json=update_data, headers=HEADERS)
print_response(response, f"Update Employee {employee_id}")

if response.status_code == 200:
    print("✅ Employee updated successfully!")
else:
    print("❌ Failed to update employee!")
# Out:
# ============================================================
# Update Employee 1
# ============================================================
# Status Code: 200
#
# Response Body:
# {'aadharNumber': '1234-5678-9012',
#  'bankAccountNumber': None,
#  'bloodGroup': 'O+',
#  'branchName': None,
#  'certifications': None,
#  'department': 'IT',
#  'dob': '1990-01-15 00:00:00',
#  'documents': None,
#  'email': 'john.doe@example.com',
#  'employeeCode': 'EMP001',
#  'esicIPNumber': None,
#  'fatherName': 'Robert Doe',
#  'firstName': 'John',
#  'gender': 'Male',
#  'height': '180cm',
#  'hireDate': '2020-01-01',
#  'id': 1,
#  'identificationMark': None,
#  'ifscCode': None,
#  'is_active': True,
#  'lastName': 'Doe',
#  'maritalStatus': True,
#  'middleName': 'Michael',
#  'mobileHome': '+0987654321',
#  'motherName': 'Mary Doe',
#  'panNumber': 'ABCDE1234F',
#  'permanentCity': 'New York',
#  'permanentState': 'NY',
#  'permanentStreet': '123 Main St',
#  'pfNumbe': None,
#  'phone': '+1234567890',
#  'position': 'Senior Software Engineer',
#  'presentCity': 'New York',
#  'presentState': 'NY',
#  'presentStreet': '123 Main St',
#  'salary': '85000.00',
#  'salaryDetails': None,
#  'shirtSize': None,
#  'shoeSize': None,
#  'spouseName': 'Jane Doe',
#  'trouserSize': None,
#  'uanNumber': None,
#  'weight': '75kg'}
# ============================================================
#
# ✅ Employee updated successfully!

# %% [markdown]
# ### 4.5 Delete Employee
#
# Delete an employee record.

# %%
# Delete employee (use with caution!)
employee_id = 2  # Change this to a valid employee ID you want to delete

response = requests.delete(f"{BASE_URL}/employee/{employee_id}/", headers=HEADERS)
print_response(response, f"Delete Employee {employee_id}")

if response.status_code == 204:
    print("✅ Employee deleted successfully!")
else:
    print("❌ Failed to delete employee!")

print("⚠️ Delete employee endpoint commented out for safety. Uncomment to test.")
# Out:
# ============================================================
# Delete Employee 2
# ============================================================
# Status Code: 204
#
# Response Body:
#
# ============================================================
#
# ✅ Employee deleted successfully!
# ⚠️ Delete employee endpoint commented out for safety. Uncomment to test.

# %% [markdown]
# ---
# ## 5. Client Management APIs <a id="clients"></a>
#
# Test all client management endpoints.

# %% [markdown]
# ### 5.1 Create Client
#
# Create a new client record.

# %%
# Create a new client
client_data = {
    "company_name": "Acme Corporation",
    "client_code": "ACME001",
    "contact_person": "Alice Johnson",
    "email": "alice@acmecorp.com",
    "phone": "+1234567890",
    "street": "456 Business Ave",
    "city": "San Francisco",
    "state": "CA",
    "zip_code": "94102",
    "country": "USA",
    "gstin": "22AAAAA0000A1Z5",
    "status": "Active",
    "contractStartDate": "2024-01-01T00:00:00Z",
    "contractEndDate": "2025-12-31T23:59:59Z",
    "units":[],
}

response = requests.post(f"{BASE_URL}/clients/", json=client_data, headers=HEADERS)
print_response(response, "Create Client")

if response.status_code == 201:
    client = response.json()
    CLIENT_ID = client.get('id')
    print(f"✅ Client created successfully with ID: {CLIENT_ID}")
else:
    print("❌ Failed to create client!")
# Out:
# ============================================================
# Create Client
# ============================================================
# Status Code: 400
#
# Response Body:
# {'client_code': ['client with this client code already exists.']}
# ============================================================
#
# ❌ Failed to create client!

# %% [markdown]
# ### 5.2 List All Clients
#
# Get a list of all clients.

# %%
# List all clients
response = requests.get(f"{BASE_URL}/clients/", headers=HEADERS)
print_response(response, "List All Clients")

if response.status_code == 200:
    clients = response.json()
    print(f"✅ Found {len(clients)} clients")
else:
    print("❌ Failed to retrieve clients!")
# Out:
# ============================================================
# List All Clients
# ============================================================
# Status Code: 200
#
# Response Body:
# {'count': 1,
#  'next': None,
#  'previous': None,
#  'results': [{'city': 'San Francisco',
#               'client_code': 'ACME001',
#               'company_name': 'Acme Corporation',
#               'contact_person': 'Alice Johnson',
#               'contractEndDate': '2025-12-31 23:59:59',
#               'contractStartDate': '2024-01-01 00:00:00',
#               'country': 'USA',
#               'created_at': '2026-02-12 13:09:24',
#               'email': 'alice@acmecorp.com',
#               'gstin': '22AAAAA0000A1Z5',
#               'id': 1,
#               'phone': '+1234567890',
#               'state': 'CA',
#               'status': 'Active',
#               'street': '456 Business Ave',
#               'units': [],
#               'zip_code': '94102'}]}
# ============================================================
#
# ✅ Found 4 clients

# %% [markdown]
# ### 5.3 Get Client by ID
#
# Retrieve details of a specific client.

# %%
# Get client by ID
client_id = 1  # Change this to a valid client ID

response = requests.get(f"{BASE_URL}/clients/{client_id}/", headers=HEADERS)
print_response(response, f"Get Client {client_id}")

if response.status_code == 200:
    print("✅ Client details retrieved successfully!")
else:
    print("❌ Failed to retrieve client details!")
# Out:
# ============================================================
# Get Client 1
# ============================================================
# Status Code: 200
#
# Response Body:
# {'city': 'San Francisco',
#  'client_code': 'ACME001',
#  'company_name': 'Acme Corporation',
#  'contact_person': 'Alice Johnson',
#  'contractEndDate': '2025-12-31 23:59:59',
#  'contractStartDate': '2024-01-01 00:00:00',
#  'country': 'USA',
#  'created_at': '2026-02-12 13:09:24',
#  'email': 'alice@acmecorp.com',
#  'gstin': '22AAAAA0000A1Z5',
#  'id': 1,
#  'phone': '+1234567890',
#  'state': 'CA',
#  'status': 'Active',
#  'street': '456 Business Ave',
#  'units': [],
#  'zip_code': '94102'}
# ============================================================
#
# ✅ Client details retrieved successfully!

# %% [markdown]
# ### 5.4 Update Client
#
# Update client information.

# %%
# Update client
client_id = 1  # Change this to a valid client ID
update_data = {
    "status": "Inactive",
    "contact_person": "Bob Smith"
}

response = requests.patch(f"{BASE_URL}/clients/{client_id}/", json=update_data, headers=HEADERS)
print_response(response, f"Update Client {client_id}")

if response.status_code == 200:
    print("✅ Client updated successfully!")
else:
    print("❌ Failed to update client!")
# Out:
# ============================================================
# Update Client 1
# ============================================================
# Status Code: 200
#
# Response Body:
# {'city': 'San Francisco',
#  'client_code': 'ACME001',
#  'company_name': 'Acme Corporation',
#  'contact_person': 'Bob Smith',
#  'contractEndDate': '2025-12-31 23:59:59',
#  'contractStartDate': '2024-01-01 00:00:00',
#  'country': 'USA',
#  'created_at': '2026-02-12 13:09:24',
#  'email': 'alice@acmecorp.com',
#  'gstin': '22AAAAA0000A1Z5',
#  'id': 1,
#  'phone': '+1234567890',
#  'state': 'CA',
#  'status': 'Inactive',
#  'street': '456 Business Ave',
#  'units': [],
#  'zip_code': '94102'}
# ============================================================
#
# ✅ Client updated successfully!

# %% [markdown]
# ### 5.5 Delete Client
#
# Delete a client record (cascades to related units).

# %%
# Delete client (use with caution! This will also delete all related units)
# client_id = 999  # Change this to a valid client ID you want to delete

# response = requests.delete(f"{BASE_URL}/clients/{client_id}/", headers=HEADERS)
# print_response(response, f"Delete Client {client_id}")

# if response.status_code == 204:
#     print("✅ Client deleted successfully!")
# else:
#     print("❌ Failed to delete client!")

print("⚠️ Delete client endpoint commented out for safety. Uncomment to test.")
# Out:
# ⚠️ Delete client endpoint commented out for safety. Uncomment to test.

# %% [markdown]
# ---
# ## 6. Client Unit APIs <a id="client-units"></a>
#
# Test all client unit management endpoints.

# %% [markdown]
# ### 6.1 Create Client Unit
#
# Create a new client unit.

# %%
# Create a new client unit
unit_data = {
    "client": 1,  # Change this to a valid client ID
    "unit_name": "Main Office",
    "unit_code": "ACME001-MAIN-001",
    "print_name": "Acme Corp - Main Office",
    "shipping_address": "456 Business Ave, San Francisco, CA 94102",
    "billing_name": "Acme Corporation",
    "billing_address": "456 Business Ave, San Francisco, CA 94102",
    "phone": "+1234567890",
    "email": "mainoffice@acmecorp.com",
    "no_of_employees": 50,
    "min_age": 18,
    "max_age": 65,
    "is_gst_applicable": True
}

response = requests.post(f"{BASE_URL}/clients/units/", json=unit_data, headers=HEADERS)
print_response(response, "Create Client Unit")

if response.status_code == 201:
    unit = response.json()
    UNIT_ID = unit.get('id')
    print(f"✅ Client unit created successfully with ID: {UNIT_ID}")
else:
    print("❌ Failed to create client unit!")
# Out:
# ============================================================
# Create Client Unit
# ============================================================
# Status Code: 201
#
# Response Body:
# {'accounts_officer': None,
#  'agreement_date': None,
#  'agreement_exp_date': None,
#  'agreement_no': None,
#  'attention': None,
#  'bank': None,
#  'bill_generate_type': None,
#  'bill_type': None,
#  'billing_address': '456 Business Ave, San Francisco, CA 94102',
#  'billing_from_state': None,
#  'billing_in_decimal': False,
#  'billing_name': 'Acme Corporation',
#  'billing_to_state': None,
#  'bonus_paid_in_month': None,
#  'contract_period_shown': None,
#  'controller': None,
#  'district': None,
#  'email': 'mainoffice@acmecorp.com',
#  'esic_code': None,
#  'fax': None,
#  'field_area': None,
#  'gst_category': None,
#  'gstin': None,
#  'id': 3,
#  'is_gst_applicable': True,
#  'is_igst_applicable': False,
#  'is_uniform_free': False,
#  'is_union_territory': False,
#  'leave_opening': None,
#  'max_age': 65,
#  'min_age': 18,
#  'nature_of_service': None,
#  'no_of_employees': 50,
#  'old_unit_code': None,
#  'operation_department': None,
#  'pan_card_no': None,
#  'pf_code': None,
#  'phone': '+1234567890',
#  'pin_code': None,
#  'place_of_supply': None,
#  'place_of_supply_address': None,
#  'print_format': None,
#  'print_name': 'Acme Corp - Main Office',
#  'professional_tax_reg_no': None,
#  'rate_structure': None,
#  'region': None,
#  'remarks': None,
#  'renewal_letter_date': None,
#  'roc': None,
#  'salary_transferred_by': None,
#  'service_tax_no': None,
#  'shipping_address': '456 Business Ave, San Francisco, CA 94102',
#  'show_leave_on_pay_slip': False,
#  'state_office': None,
#  'system_billing': False,
#  'tan_no': None,
#  'tin_no': None,
#  'unit_code': 'ACME001-MAIN-OFFICE-3',
#  'unit_name': 'Main Office',
#  'vendor_code': None,
#  'wages_revision': None,
#  'website': None,
#  'work_completion_date': None,
#  'work_order_date': None,
#  'work_order_no': None,
#  'work_start_date': None}
# ============================================================
#
# ✅ Client unit created successfully with ID: 3

# %% [markdown]
# ### 6.2 List All Client Units
#
# Get a list of all client units.

# %%
# List all client units
response = requests.get(f"{BASE_URL}/clients/units/", headers=HEADERS)
print_response(response, "List All Client Units")

if response.status_code == 200:
    units = response.json()
    print(f"✅ Found {len(units)} client units")
else:
    print("❌ Failed to retrieve client units!")
# Out:
# ============================================================
# List All Client Units
# ============================================================
# Status Code: 200
#
# Response Body:
# {'count': 3,
#  'next': None,
#  'previous': None,
#  'results': [{'accounts_officer': {'designation': None,
#                                    'email': 'acct1@example.com',
#                                    'id': 1,
#                                    'mobile': None,
#                                    'name': 'Acct Officer 1',
#                                    'phone': '1234567890'},
#               'agreement_date': None,
#               'agreement_exp_date': None,
#               'agreement_no': None,
#               'attention': None,
#               'bank': None,
#               'bill_generate_type': None,
#               'bill_type': None,
#               'billing_address': None,
#               'billing_from_state': None,
#               'billing_in_decimal': False,
#               'billing_name': 'Test Unit Billing Details',
#               'billing_to_state': None,
#               'bonus_paid_in_month': None,
#               'contract_period_shown': None,
#               'controller': None,
#               'district': None,
#               'email': None,
#               'esic_code': None,
#               'fax': None,
#               'field_area': None,
#               'gst_category': None,
#               'gstin': None,
#               'id': 1,
#               'is_gst_applicable': True,
#               'is_igst_applicable': False,
#               'is_uniform_free': False,
#               'is_union_territory': False,
#               'leave_opening': None,
#               'max_age': None,
#               'min_age': None,
#               'nature_of_service': None,
#               'no_of_employees': None,
#               'old_unit_code': None,
#               'operation_department': {'designation': None,
#                                        'email': 'ops1@example.com',
#                                        'id': 2,
#                                        'mobile': None,
#                                        'name': 'Ops Manager 1',
#                                        'phone': None},
#               'pan_card_no': None,
#               'pf_code': None,
#               'phone': None,
#               'pin_code': None,
#               'place_of_supply': None,
#               'place_of_supply_address': None,
#               'print_format': None,
#               'print_name': None,
#               'professional_tax_reg_no': None,
#               'rate_structure': None,
#               'region': None,
#               'remarks': None,
#               'renewal_letter_date': None,
#               'roc': None,
#               'salary_transferred_by': None,
#               'service_tax_no': None,
#               'shipping_address': None,
#               'show_leave_on_pay_slip': False,
#               'state_office': None,
#               'system_billing': False,
#               'tan_no': None,
#               'tin_no': None,
#               'unit_code': 'TC-1770906373-TEST-UNIT-ALPHA-1',
#               'unit_name': 'Test Unit Alpha',
#               'vendor_code': None,
#               'wages_revision': None,
#               'website': None,
#               'work_completion_date': None,
#               'work_order_date': None,
#               'work_order_no': None,
#               'work_start_date': None},
#              {'accounts_officer': {'designation': None,
#                                    'email': 'acct1@example.com',
#                                    'id': 3,
#                                    'mobile': None,
#                                    'name': 'Acct Officer 1',
#                                    'phone': '1234567890'},
#               'agreement_date': None,
#               'agreement_exp_date': None,
#               'agreement_no': None,
#               'attention': None,
#               'bank': None,
#               'bill_generate_type': None,
#               'bill_type': None,
#               'billing_address': None,
#               'billing_from_state': None,
#               'billing_in_decimal': False,
#               'billing_name': 'Test Unit Billing Details',
#               'billing_to_state': None,
#               'bonus_paid_in_month': None,
#               'contract_period_shown': None,
#               'controller': None,
#               'district': None,
#               'email': None,
#               'esic_code': None,
#               'fax': None,
#               'field_area': None,
#               'gst_category': None,
#               'gstin': None,
#               'id': 2,
#               'is_gst_applicable': True,
#               'is_igst_applicable': False,
#               'is_uniform_free': False,
#               'is_union_territory': False,
#               'leave_opening': None,
#               'max_age': None,
#               'min_age': None,
#               'nature_of_service': None,
#               'no_of_employees': None,
#               'old_unit_code': None,
#               'operation_department': {'designation': None,
#                                        'email': 'ops1@example.com',
#                                        'id': 4,
#                                        'mobile': None,
#                                        'name': 'Ops Manager 1',
#                                        'phone': None},
#               'pan_card_no': None,
#               'pf_code': None,
#               'phone': None,
#               'pin_code': None,
#               'place_of_supply': None,
#               'place_of_supply_address': None,
#               'print_format': None,
#               'print_name': None,
#               'professional_tax_reg_no': None,
#               'rate_structure': None,
#               'region': None,
#               'remarks': None,
#               'renewal_letter_date': None,
#               'roc': None,
#               'salary_transferred_by': None,
#               'service_tax_no': None,
#               'shipping_address': None,
#               'show_leave_on_pay_slip': False,
#               'state_office': None,
#               'system_billing': False,
#               'tan_no': None,
#               'tin_no': None,
#               'unit_code': 'TC-1770906427-TEST-UNIT-ALPHA-2',
#               'unit_name': 'Test Unit Alpha',
#               'vendor_code': None,
#               'wages_revision': None,
#               'website': None,
#               'work_completion_date': None,
#               'work_order_date': None,
#               'work_order_no': None,
#               'work_start_date': None},
#              {'accounts_officer': None,
#               'agreement_date': None,
#               'agreement_exp_date': None,
#               'agreement_no': None,
#               'attention': None,
#               'bank': None,
#               'bill_generate_type': None,
#               'bill_type': None,
#               'billing_address': '456 Business Ave, San Francisco, CA 94102',
#               'billing_from_state': None,
#               'billing_in_decimal': False,
#               'billing_name': 'Acme Corporation',
#               'billing_to_state': None,
#               'bonus_paid_in_month': None,
#               'contract_period_shown': None,
#               'controller': None,
#               'district': None,
#               'email': 'mainoffice@acmecorp.com',
#               'esic_code': None,
#               'fax': None,
#               'field_area': None,
#               'gst_category': None,
#               'gstin': None,
#               'id': 3,
#               'is_gst_applicable': True,
#               'is_igst_applicable': False,
#               'is_uniform_free': False,
#               'is_union_territory': False,
#               'leave_opening': None,
#               'max_age': 65,
#               'min_age': 18,
#               'nature_of_service': None,
#               'no_of_employees': 50,
#               'old_unit_code': None,
#               'operation_department': None,
#               'pan_card_no': None,
#               'pf_code': None,
#               'phone': '+1234567890',
#               'pin_code': None,
#               'place_of_supply': None,
#               'place_of_supply_address': None,
#               'print_format': None,
#               'print_name': 'Acme Corp - Main Office',
#               'professional_tax_reg_no': None,
#               'rate_structure': None,
#               'region': None,
#               'remarks': None,
#               'renewal_letter_date': None,
#               'roc': None,
#               'salary_transferred_by': None,
#               'service_tax_no': None,
#               'shipping_address': '456 Business Ave, San Francisco, CA 94102',
#               'show_leave_on_pay_slip': False,
#               'state_office': None,
#               'system_billing': False,
#               'tan_no': None,
#               'tin_no': None,
#               'unit_code': 'ACME001-MAIN-OFFICE-3',
#               'unit_name': 'Main Office',
#               'vendor_code': None,
#               'wages_revision': None,
#               'website': None,
#               'work_completion_date': None,
#               'work_order_date': None,
#               'work_order_no': None,
#               'work_start_date': None}]}
# ============================================================
#
# ✅ Found 4 client units

# %% [markdown]
# ### 6.3 Get Client Unit by ID
#
# Retrieve details of a specific client unit.

# %%
# Get client unit by ID
unit_id = 1  # Change this to a valid unit ID

response = requests.get(f"{BASE_URL}/clients/units/{unit_id}/", headers=HEADERS)
print_response(response, f"Get Client Unit {unit_id}")

if response.status_code == 200:
    print("✅ Client unit details retrieved successfully!")
else:
    print("❌ Failed to retrieve client unit details!")
# Out:
# ============================================================
# Get Client Unit 1
# ============================================================
# Status Code: 200
#
# Response Body:
# {'accounts_officer': {'designation': None,
#                       'email': 'acct1@example.com',
#                       'id': 1,
#                       'mobile': None,
#                       'name': 'Acct Officer 1',
#                       'phone': '1234567890'},
#  'agreement_date': None,
#  'agreement_exp_date': None,
#  'agreement_no': None,
#  'attention': None,
#  'bank': None,
#  'bill_generate_type': None,
#  'bill_type': None,
#  'billing_address': None,
#  'billing_from_state': None,
#  'billing_in_decimal': False,
#  'billing_name': 'Test Unit Billing Details',
#  'billing_to_state': None,
#  'bonus_paid_in_month': None,
#  'contract_period_shown': None,
#  'controller': None,
#  'district': None,
#  'email': None,
#  'esic_code': None,
#  'fax': None,
#  'field_area': None,
#  'gst_category': None,
#  'gstin': None,
#  'id': 1,
#  'is_gst_applicable': True,
#  'is_igst_applicable': False,
#  'is_uniform_free': False,
#  'is_union_territory': False,
#  'leave_opening': None,
#  'max_age': None,
#  'min_age': None,
#  'nature_of_service': None,
#  'no_of_employees': None,
#  'old_unit_code': None,
#  'operation_department': {'designation': None,
#                           'email': 'ops1@example.com',
#                           'id': 2,
#                           'mobile': None,
#                           'name': 'Ops Manager 1',
#                           'phone': None},
#  'pan_card_no': None,
#  'pf_code': None,
#  'phone': None,
#  'pin_code': None,
#  'place_of_supply': None,
#  'place_of_supply_address': None,
#  'print_format': None,
#  'print_name': None,
#  'professional_tax_reg_no': None,
#  'rate_structure': None,
#  'region': None,
#  'remarks': None,
#  'renewal_letter_date': None,
#  'roc': None,
#  'salary_transferred_by': None,
#  'service_tax_no': None,
#  'shipping_address': None,
#  'show_leave_on_pay_slip': False,
#  'state_office': None,
#  'system_billing': False,
#  'tan_no': None,
#  'tin_no': None,
#  'unit_code': 'TC-1770906373-TEST-UNIT-ALPHA-1',
#  'unit_name': 'Test Unit Alpha',
#  'vendor_code': None,
#  'wages_revision': None,
#  'website': None,
#  'work_completion_date': None,
#  'work_order_date': None,
#  'work_order_no': None,
#  'work_start_date': None}
# ============================================================
#
# ✅ Client unit details retrieved successfully!

# %% [markdown]
# ### 6.4 Update Client Unit
#
# Update client unit information.

# %%
# Update client unit
unit_id = 1  # Change this to a valid unit ID
update_data = {
    "no_of_employees": 75,
    "phone": "+1234567899"
}

response = requests.patch(f"{BASE_URL}/clients/units/{unit_id}/", json=update_data, headers=HEADERS)
print_response(response, f"Update Client Unit {unit_id}")

if response.status_code == 200:
    print("✅ Client unit updated successfully!")
else:
    print("❌ Failed to update client unit!")
# Out:
# ============================================================
# Update Client Unit 1
# ============================================================
# Status Code: 200
#
# Response Body:
# {'accounts_officer': {'designation': None,
#                       'email': 'acct1@example.com',
#                       'id': 1,
#                       'mobile': None,
#                       'name': 'Acct Officer 1',
#                       'phone': '1234567890'},
#  'agreement_date': None,
#  'agreement_exp_date': None,
#  'agreement_no': None,
#  'attention': None,
#  'bank': None,
#  'bill_generate_type': None,
#  'bill_type': None,
#  'billing_address': None,
#  'billing_from_state': None,
#  'billing_in_decimal': False,
#  'billing_name': 'Test Unit Billing Details',
#  'billing_to_state': None,
#  'bonus_paid_in_month': None,
#  'contract_period_shown': None,
#  'controller': None,
#  'district': None,
#  'email': None,
#  'esic_code': None,
#  'fax': None,
#  'field_area': None,
#  'gst_category': None,
#  'gstin': None,
#  'id': 1,
#  'is_gst_applicable': True,
#  'is_igst_applicable': False,
#  'is_uniform_free': False,
#  'is_union_territory': False,
#  'leave_opening': None,
#  'max_age': None,
#  'min_age': None,
#  'nature_of_service': None,
#  'no_of_employees': 75,
#  'old_unit_code': None,
#  'operation_department': {'designation': None,
#                           'email': 'ops1@example.com',
#                           'id': 2,
#                           'mobile': None,
#                           'name': 'Ops Manager 1',
#                           'phone': None},
#  'pan_card_no': None,
#  'pf_code': None,
#  'phone': '+1234567899',
#  'pin_code': None,
#  'place_of_supply': None,
#  'place_of_supply_address': None,
#  'print_format': None,
#  'print_name': None,
#  'professional_tax_reg_no': None,
#  'rate_structure': None,
#  'region': None,
#  'remarks': None,
#  'renewal_letter_date': None,
#  'roc': None,
#  'salary_transferred_by': None,
#  'service_tax_no': None,
#  'shipping_address': None,
#  'show_leave_on_pay_slip': False,
#  'state_office': None,
#  'system_billing': False,
#  'tan_no': None,
#  'tin_no': None,
#  'unit_code': 'TC-1770906373-TEST-UNIT-ALPHA-1',
#  'unit_name': 'Test Unit Alpha',
#  'vendor_code': None,
#  'wages_revision': None,
#  'website': None,
#  'work_completion_date': None,
#  'work_order_date': None,
#  'work_order_no': None,
#  'work_start_date': None}
# ============================================================
#
# ✅ Client unit updated successfully!

# %% [markdown]
# ### 6.5 Delete Client Unit
#
# Delete a client unit.

# %%
# Delete client unit (use with caution!)
# unit_id = 999  # Change this to a valid unit ID you want to delete

# response = requests.delete(f"{BASE_URL}/clients/units/{unit_id}/", headers=HEADERS)
# print_response(response, f"Delete Client Unit {unit_id}")

# if response.status_code == 204:
#     print("✅ Client unit deleted successfully!")
# else:
#     print("❌ Failed to delete client unit!")

print("⚠️ Delete client unit endpoint commented out for safety. Uncomment to test.")
# Out:
# ⚠️ Delete client unit endpoint commented out for safety. Uncomment to test.

# %% [markdown]
# ---
# ## 7. Department Contact APIs <a id="department-contacts"></a>
#
# Test all department contact management endpoints.

# %% [markdown]
# ### 7.1 Create Department Contact
#
# Create a new department contact.

# %%
# Create a new department contact
contact_data = {
    "name": "Sarah Williams",
    "designation": "Accounts Manager",
    "phone": "+1234567890",
    "mobile": "+0987654321",
    "email": "sarah.williams@acmecorp.com"
}

response = requests.post(f"{BASE_URL}/clients/contacts/", json=contact_data, headers=HEADERS)
print_response(response, "Create Department Contact")

if response.status_code == 201:
    contact = response.json()
    CONTACT_ID = contact.get('id')
    print(f"✅ Department contact created successfully with ID: {CONTACT_ID}")
else:
    print("❌ Failed to create department contact!")
# Out:
# ============================================================
# Create Department Contact
# ============================================================
# Status Code: 201
#
# Response Body:
# {'designation': 'Accounts Manager',
#  'email': 'sarah.williams@acmecorp.com',
#  'id': 5,
#  'mobile': '+0987654321',
#  'name': 'Sarah Williams',
#  'phone': '+1234567890'}
# ============================================================
#
# ✅ Department contact created successfully with ID: 5

# %% [markdown]
# ### 7.2 List All Department Contacts
#
# Get a list of all department contacts.

# %%
# List all department contacts
response = requests.get(f"{BASE_URL}/clients/contacts/", headers=HEADERS)
print_response(response, "List All Department Contacts")

if response.status_code == 200:
    contacts = response.json()
    print(f"✅ Found {len(contacts)} department contacts")
else:
    print("❌ Failed to retrieve department contacts!")
# Out:
# ============================================================
# List All Department Contacts
# ============================================================
# Status Code: 200
#
# Response Body:
# {'count': 5,
#  'next': None,
#  'previous': None,
#  'results': [{'designation': None,
#               'email': 'acct1@example.com',
#               'id': 1,
#               'mobile': None,
#               'name': 'Acct Officer 1',
#               'phone': '1234567890'},
#              {'designation': None,
#               'email': 'ops1@example.com',
#               'id': 2,
#               'mobile': None,
#               'name': 'Ops Manager 1',
#               'phone': None},
#              {'designation': None,
#               'email': 'acct1@example.com',
#               'id': 3,
#               'mobile': None,
#               'name': 'Acct Officer 1',
#               'phone': '1234567890'},
#              {'designation': None,
#               'email': 'ops1@example.com',
#               'id': 4,
#               'mobile': None,
#               'name': 'Ops Manager 1',
#               'phone': None},
#              {'designation': 'Accounts Manager',
#               'email': 'sarah.williams@acmecorp.com',
#               'id': 5,
#               'mobile': '+0987654321',
#               'name': 'Sarah Williams',
#               'phone': '+1234567890'}]}
# ============================================================
#
# ✅ Found 4 department contacts

# %% [markdown]
# ### 7.3 Get Department Contact by ID
#
# Retrieve details of a specific department contact.

# %%
# Get department contact by ID
contact_id = 1  # Change this to a valid contact ID

response = requests.get(f"{BASE_URL}/clients/contacts/{contact_id}/", headers=HEADERS)
print_response(response, f"Get Department Contact {contact_id}")

if response.status_code == 200:
    print("✅ Department contact details retrieved successfully!")
else:
    print("❌ Failed to retrieve department contact details!")
# Out:
# ============================================================
# Get Department Contact 1
# ============================================================
# Status Code: 200
#
# Response Body:
# {'designation': None,
#  'email': 'acct1@example.com',
#  'id': 1,
#  'mobile': None,
#  'name': 'Acct Officer 1',
#  'phone': '1234567890'}
# ============================================================
#
# ✅ Department contact details retrieved successfully!

# %% [markdown]
# ### 7.4 Update Department Contact
#
# Update department contact information.

# %%
# Update department contact
contact_id = 1  # Change this to a valid contact ID
update_data = {
    "designation": "Senior Accounts Manager",
    "mobile": "+1111111111"
}

response = requests.patch(f"{BASE_URL}/clients/contacts/{contact_id}/", json=update_data, headers=HEADERS)
print_response(response, f"Update Department Contact {contact_id}")

if response.status_code == 200:
    print("✅ Department contact updated successfully!")
else:
    print("❌ Failed to update department contact!")
# Out:
# ============================================================
# Update Department Contact 1
# ============================================================
# Status Code: 404
#
# Response Body:
# {'detail': 'No DepartmentContact matches the given query.'}
# ============================================================
#
# ❌ Failed to update department contact!

# %% [markdown]
# ### 7.5 Delete Department Contact
#
# Delete a department contact.

# %%
# Delete department contact (use with caution!)
# contact_id = 999  # Change this to a valid contact ID you want to delete

# response = requests.delete(f"{BASE_URL}/clients/contacts/{contact_id}/", headers=HEADERS)
# print_response(response, f"Delete Department Contact {contact_id}")

# if response.status_code == 204:
#     print("✅ Department contact deleted successfully!")
# else:
#     print("❌ Failed to delete department contact!")

print("⚠️ Delete department contact endpoint commented out for safety. Uncomment to test.")
# Out:
# ⚠️ Delete department contact endpoint commented out for safety. Uncomment to test.

# %% [markdown]
# ---
# ## 8. Advanced Testing Scenarios
#
# Additional test scenarios for filtering, searching, and pagination.

# %% [markdown]
# ### 8.1 User Filtering and Search
#
# Test filtering and search functionality for users.

# %%
# Filter active users
response = requests.get(f"{BASE_URL}/users/?is_active=true", headers=HEADERS)
print_response(response, "Filter Active Users")

# Search users by name
response = requests.get(f"{BASE_URL}/users/?search=test", headers=HEADERS)
print_response(response, "Search Users by Name")

# Order users by creation date
response = requests.get(f"{BASE_URL}/users/?ordering=-created_at", headers=HEADERS)
print_response(response, "Order Users by Creation Date (Descending)")
# Out:
# ============================================================
# Filter Active Users
# ============================================================
# Status Code: 200
#
# Response Body:
# {'count': 9,
#  'next': None,
#  'previous': None,
#  'results': [{'created_at': '2026-02-12 14:27:11',
#               'email': 'testuser_1770906427@example.com',
#               'id': 9,
#               'is_active': True,
#               'is_staff': False,
#               'is_superuser': False,
#               'name': 'Test User',
#               'updated_at': '2026-02-12 14:27:11'},
#              {'created_at': '2026-02-12 14:26:16',
#               'email': 'testuser_1770906373@example.com',
#               'id': 8,
#               'is_active': True,
#               'is_staff': False,
#               'is_superuser': False,
#               'name': 'Test User',
#               'updated_at': '2026-02-12 14:26:16'},
#              {'created_at': '2026-02-12 14:24:56',
#               'email': 'testuser_1770906293@example.com',
#               'id': 7,
#               'is_active': True,
#               'is_staff': False,
#               'is_superuser': False,
#               'name': 'Test User',
#               'updated_at': '2026-02-12 14:24:56'},
#              {'created_at': '2026-02-12 14:21:11',
#               'email': 'testuser_1770906068@example.com',
#               'id': 6,
#               'is_active': True,
#               'is_staff': False,
#               'is_superuser': False,
#               'name': 'Test User',
#               'updated_at': '2026-02-12 14:21:11'},
#              {'created_at': '2026-02-12 14:20:14',
#               'email': 'testuser_1770906011@example.com',
#               'id': 5,
#               'is_active': True,
#               'is_staff': False,
#               'is_superuser': False,
#               'name': 'Test User',
#               'updated_at': '2026-02-12 14:20:14'},
#              {'created_at': '2026-02-12 14:19:45',
#               'email': 'testuser_1770905981@example.com',
#               'id': 4,
#               'is_active': True,
#               'is_staff': False,
#               'is_superuser': False,
#               'name': 'Test User',
#               'updated_at': '2026-02-12 14:19:45'},
#              {'created_at': '2026-02-12 14:18:32',
#               'email': 'testuser_1770905908@example.com',
#               'id': 3,
#               'is_active': True,
#               'is_staff': False,
#               'is_superuser': False,
#               'name': 'Test User',
#               'updated_at': '2026-02-12 14:18:32'},
#              {'created_at': '2026-02-12 14:18:06',
#               'email': 'testuser_1770905883@example.com',
#               'id': 2,
#               'is_active': True,
#               'is_staff': False,
#               'is_superuser': False,
#               'name': 'Test User',
#               'updated_at': '2026-02-12 14:18:06'},
#              {'created_at': '2026-02-12 12:40:12',
#               'email': 'testuser@example.com',
#               'id': 1,
#               'is_active': True,
#               'is_staff': False,
#               'is_superuser': False,
#               'name': 'Updated Test User',
#               'updated_at': '2026-02-12 13:04:38'}]}
# ============================================================
#
#
# ============================================================
# Search Users by Name
# ============================================================
# Status Code: 200
#
# Response Body:
# {'count': 9,
#  'next': None,
#  'previous': None,
#  'results': [{'created_at': '2026-02-12 14:27:11',
#               'email': 'testuser_1770906427@example.com',
#               'id': 9,
#               'is_active': True,
#               'is_staff': False,
#               'is_superuser': False,
#               'name': 'Test User',
#               'updated_at': '2026-02-12 14:27:11'},
#              {'created_at': '2026-02-12 14:26:16',
#               'email': 'testuser_1770906373@example.com',
#               'id': 8,
#               'is_active': True,
#               'is_staff': False,
#               'is_superuser': False,
#               'name': 'Test User',
#               'updated_at': '2026-02-12 14:26:16'},
#              {'created_at': '2026-02-12 14:24:56',
#               'email': 'testuser_1770906293@example.com',
#               'id': 7,
#               'is_active': True,
#               'is_staff': False,
#               'is_superuser': False,
#               'name': 'Test User',
#               'updated_at': '2026-02-12 14:24:56'},
#              {'created_at': '2026-02-12 14:21:11',
#               'email': 'testuser_1770906068@example.com',
#               'id': 6,
#               'is_active': True,
#               'is_staff': False,
#               'is_superuser': False,
#               'name': 'Test User',
#               'updated_at': '2026-02-12 14:21:11'},
#              {'created_at': '2026-02-12 14:20:14',
#               'email': 'testuser_1770906011@example.com',
#               'id': 5,
#               'is_active': True,
#               'is_staff': False,
#               'is_superuser': False,
#               'name': 'Test User',
#               'updated_at': '2026-02-12 14:20:14'},
#              {'created_at': '2026-02-12 14:19:45',
#               'email': 'testuser_1770905981@example.com',
#               'id': 4,
#               'is_active': True,
#               'is_staff': False,
#               'is_superuser': False,
#               'name': 'Test User',
#               'updated_at': '2026-02-12 14:19:45'},
#              {'created_at': '2026-02-12 14:18:32',
#               'email': 'testuser_1770905908@example.com',
#               'id': 3,
#               'is_active': True,
#               'is_staff': False,
#               'is_superuser': False,
#               'name': 'Test User',
#               'updated_at': '2026-02-12 14:18:32'},
#              {'created_at': '2026-02-12 14:18:06',
#               'email': 'testuser_1770905883@example.com',
#               'id': 2,
#               'is_active': True,
#               'is_staff': False,
#               'is_superuser': False,
#               'name': 'Test User',
#               'updated_at': '2026-02-12 14:18:06'},
#              {'created_at': '2026-02-12 12:40:12',
#               'email': 'testuser@example.com',
#               'id': 1,
#               'is_active': True,
#               'is_staff': False,
#               'is_superuser': False,
#               'name': 'Updated Test User',
#               'updated_at': '2026-02-12 13:04:38'}]}
# ============================================================
#
#
# ============================================================
# Order Users by Creation Date (Descending)
# ============================================================
# Status Code: 200
#
# Response Body:
# {'count': 9,
#  'next': None,
#  'previous': None,
#  'results': [{'created_at': '2026-02-12 14:27:11',
#               'email': 'testuser_1770906427@example.com',
#               'id': 9,
#               'is_active': True,
#               'is_staff': False,
#               'is_superuser': False,
#               'name': 'Test User',
#               'updated_at': '2026-02-12 14:27:11'},
#              {'created_at': '2026-02-12 14:26:16',
#               'email': 'testuser_1770906373@example.com',
#               'id': 8,
#               'is_active': True,
#               'is_staff': False,
#               'is_superuser': False,
#               'name': 'Test User',
#               'updated_at': '2026-02-12 14:26:16'},
#              {'created_at': '2026-02-12 14:24:56',
#               'email': 'testuser_1770906293@example.com',
#               'id': 7,
#               'is_active': True,
#               'is_staff': False,
#               'is_superuser': False,
#               'name': 'Test User',
#               'updated_at': '2026-02-12 14:24:56'},
#              {'created_at': '2026-02-12 14:21:11',
#               'email': 'testuser_1770906068@example.com',
#               'id': 6,
#               'is_active': True,
#               'is_staff': False,
#               'is_superuser': False,
#               'name': 'Test User',
#               'updated_at': '2026-02-12 14:21:11'},
#              {'created_at': '2026-02-12 14:20:14',
#               'email': 'testuser_1770906011@example.com',
#               'id': 5,
#               'is_active': True,
#               'is_staff': False,
#               'is_superuser': False,
#               'name': 'Test User',
#               'updated_at': '2026-02-12 14:20:14'},
#              {'created_at': '2026-02-12 14:19:45',
#               'email': 'testuser_1770905981@example.com',
#               'id': 4,
#               'is_active': True,
#               'is_staff': False,
#               'is_superuser': False,
#               'name': 'Test User',
#               'updated_at': '2026-02-12 14:19:45'},
#              {'created_at': '2026-02-12 14:18:32',
#               'email': 'testuser_1770905908@example.com',
#               'id': 3,
#               'is_active': True,
#               'is_staff': False,
#               'is_superuser': False,
#               'name': 'Test User',
#               'updated_at': '2026-02-12 14:18:32'},
#              {'created_at': '2026-02-12 14:18:06',
#               'email': 'testuser_1770905883@example.com',
#               'id': 2,
#               'is_active': True,
#               'is_staff': False,
#               'is_superuser': False,
#               'name': 'Test User',
#               'updated_at': '2026-02-12 14:18:06'},
#              {'created_at': '2026-02-12 12:40:12',
#               'email': 'testuser@example.com',
#               'id': 1,
#               'is_active': True,
#               'is_staff': False,
#               'is_superuser': False,
#               'name': 'Updated Test User',
#               'updated_at': '2026-02-12 13:04:38'}]}
# ============================================================

# %% [markdown]
# ### 8.2 Error Handling Tests
#
# Test error scenarios and validation.

# %%
# Test invalid login
invalid_login = {
    "email": "invalid@example.com",
    "password": "wrongpassword"
}
response = requests.post(f"{BASE_URL}/token/", json=invalid_login, headers=HEADERS)
print_response(response, "Invalid Login Test")

# Test accessing protected endpoint without token
no_auth_headers = {"Content-Type": "application/json"}
response = requests.get(f"{BASE_URL}/users/me/", headers=no_auth_headers)
print_response(response, "Access Protected Endpoint Without Token")

# Test creating user with invalid data
invalid_user = {
    "name": "Test",
    "email": "invalid-email",  # Invalid email format
    "password": "123"  # Too short
}
response = requests.post(f"{BASE_URL}/users/", json=invalid_user, headers=HEADERS)
print_response(response, "Create User with Invalid Data")
# Out:
# ============================================================
# Invalid Login Test
# ============================================================
# Status Code: 401
#
# Response Body:
# {'detail': 'No active account found with the given credentials'}
# ============================================================
#
#
# ============================================================
# Access Protected Endpoint Without Token
# ============================================================
# Status Code: 401
#
# Response Body:
# {'detail': 'Authentication credentials were not provided.'}
# ============================================================
#
#
# ============================================================
# Create User with Invalid Data
# ============================================================
# Status Code: 400
#
# Response Body:
# {'email': ['Enter a valid email address.'],
#  'password': ['This password is too short. It must contain at least 8 '
#               'characters.',
#               'This password is too common.',
#               'This password is entirely numeric.'],
#  'password_confirm': ['This field is required.']}
# ============================================================

# %% [markdown]
# ---
# ## Summary
#
# This notebook covers comprehensive testing of all REST API endpoints in the Management System:
#
# ✅ **Authentication**: Login, Token Refresh, Token Verification
#
# ✅ **User Management**: CRUD operations, Profile, Password Change, Statistics
#
# ✅ **Employee Management**: CRUD operations for employee records
#
# ✅ **Client Management**: CRUD operations for client records
#
# ✅ **Client Unit Management**: CRUD operations for client units
#
# ✅ **Department Contact Management**: CRUD operations for department contacts
#
# ✅ **Advanced Features**: Filtering, Searching, Ordering, Error Handling
#
# ### Next Steps:
# 1. Make sure your Django backend is running on `http://localhost:8000`
# 2. Update the `BASE_URL` in the setup section if needed
# 3. Run the cells sequentially to test all endpoints
# 4. Modify the test data as needed for your specific use case
#
# ### Notes:
# - Delete operations are commented out for safety
# - Some endpoints require admin privileges
# - Make sure to have valid IDs when testing specific resource endpoints
# - Check the Swagger documentation at `http://localhost:8000/swagger/` for more details
